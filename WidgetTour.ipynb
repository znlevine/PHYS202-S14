# %% [markdown]
# # Widgets and Interactive Data Analysis

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#scattering
fig, ax=plt.subplots()
np.random.seed(0)
x,y=np.random.normal(size=(2,200))
color,size=np.random.random((2,200))

ax.scatter(x,y,c=color,s=500*size,alpha=0.3)
ax.grid(color='lightgray',alpha=.7)

# %%
import mpld3
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig264094399871760410686280"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# function create_fig264094399871760410686280(){
#
# ...

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

import mpld3
from mpld3 import plugins, utils

data = load_iris()
X=data.data
y=data.target

X+=0.1*np.random.random(X.shape)

fig,ax=plt.subplots(4,4,sharex="col",sharey="row",figsize=(8,8))
fig.subplots_adjust(left=0.05,right=0.95,bottom=0.05,top=0.95,hspace=0.1,wspace=0.1)

for i in range(4):
    for j in range(4):
        points=ax[3-i,j].scatter(X[:,j],X[:,i],c=y,s=40,alpha=0.6)
        
for axi in ax.flat:
    for axis in [axi.xaxis,axi.yaxis]:
        axis.set_major_formatter(plt.NullFormatter())
        
plugins.connect(fig, plugins.LinkedBrush(points))

mpld3.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-5a2fed055017> in <module>()
#      24         axis.set_major_formatter(plt.NullFormatter())
#      25
# ---> 26 plugins.connect(fig, plugins.LinkedBrush(points))
#      27
#      28 mpld3.display()
#
# AttributeError: 'module' object has no attribute 'LinkedBrush'

# %%
import matplotlib.pyplot as plt
import numpy as np

import mpld3
from mpld3 import plugins

fig,ax=plt.subplots()

x=np.linspace(-2,2,20)
y=x[:,None]
X=np.zeros((20,20,4))

X[:,:,0]= np.exp(-(x-1)**2-(y)**2)
X[:,:,1]= np.exp(-(x+.71)**2-(y-.71)**2)
X[:,:,2]= np.exp(-(x+.71)**2-(y+.71)**2)
X[:,:,3]= np.exp(-.25*(x**2+y**2))

im=ax.imshow(X,extent=(10,20,10,20),origin='lower',zorder=1,interpolation='nearest')
fig.colorbar(im,ax=ax)

ax.set_title('A better Image',size=20)

plugins.connect(fig,plugins.MousePosition(fontsize=14))

mpld3.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-b0b06ac05fa1> in <module>()
#      21 ax.set_title('A better Image',size=20)
#      22
# ---> 23 plugins.connect(fig,plugins.MousePosition(fontsize=14))
#      24
#      25 mpld3.display()
#
# AttributeError: 'module' object has no attribute 'MousePosition'
